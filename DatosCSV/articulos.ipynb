# %% [markdown]
# Este archivo convierte los datos del archivo .xlsx a un dataframe, crea una nueva columna con el nombre AlumnoID con números aleatorios del 1-5000, para simular que alumnos tiene uno o más artículos científicos publicados.

# %%
# !pip install pandas

# %% [markdown]
# Esta libreria permite leer archivos .xlsx y devuelve un dataframe

# %%
# !pip install openpyxl
# Out:
# ...
#
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    ---------------------------------------- 2/2 [openpyxl]
#
# ...

# %%
import pandas as pd

# %%
import numpy as np

# %%
data= pd.read_excel('dataset.xlsx', sheet_name='Articulos')

# %%
data
# Out:
#         ANO      TIPO                        NOMBRE UNIVERSIDAD  \
# 0      2020  ARTICULO              ESCUELA POLITECNICA NACIONAL
# 1      2020  ARTICULO              ESCUELA POLITECNICA NACIONAL
# 2      2020  ARTICULO              ESCUELA POLITECNICA NACIONAL
# 3      2020  ARTICULO              ESCUELA POLITECNICA NACIONAL
# 4      2020  ARTICULO              ESCUELA POLITECNICA NACIONAL
# ...     ...       ...                                       ...
# 50415  2023  ARTICULO  UNIVERSIDAD NACIONAL DE EDUCACION 'UNAE'
# 50416  2023  ARTICULO  UNIVERSIDAD NACIONAL DE EDUCACION 'UNAE'
# 50417  2023  ARTICULO  UNIVERSIDAD NACIONAL DE EDUCACION 'UNAE'
# 50418  2023  ARTICULO                       UNIVERSIDAD DEL RÍO
# 50419  2023  ARTICULO                       UNIVERSIDAD DEL RÍO
#
#              TIPO FINANCIAMIENTO PROVINCIA UNIVERSIDAD BASE DATOS INDEXADA  \
# 0                        PUBLICA             PICHINCHA              SCOPUS
# ...

# %%
#calcula el número de filas del dataframe
n = len(data)
print(n)
# Out:
# 50420

# %%
#variable auxiliar para crear la nueva columna con números aleatorios
aux = np.random.randint(1, 5001, size=n)
# Out:
# array([4137,  962, 4812, ..., 4785, 2602, 2862],
#       shape=(50420,), dtype=int32)

# %%
data['AlumnoID'] = aux

# %%
data
# Out:
#         ANO      TIPO                        NOMBRE UNIVERSIDAD  \
# 0      2020  ARTICULO              ESCUELA POLITECNICA NACIONAL
# 1      2020  ARTICULO              ESCUELA POLITECNICA NACIONAL
# 2      2020  ARTICULO              ESCUELA POLITECNICA NACIONAL
# 3      2020  ARTICULO              ESCUELA POLITECNICA NACIONAL
# 4      2020  ARTICULO              ESCUELA POLITECNICA NACIONAL
# ...     ...       ...                                       ...
# 50415  2023  ARTICULO  UNIVERSIDAD NACIONAL DE EDUCACION 'UNAE'
# 50416  2023  ARTICULO  UNIVERSIDAD NACIONAL DE EDUCACION 'UNAE'
# 50417  2023  ARTICULO  UNIVERSIDAD NACIONAL DE EDUCACION 'UNAE'
# 50418  2023  ARTICULO                       UNIVERSIDAD DEL RÍO
# 50419  2023  ARTICULO                       UNIVERSIDAD DEL RÍO
#
#              TIPO FINANCIAMIENTO PROVINCIA UNIVERSIDAD BASE DATOS INDEXADA  \
# 0                        PUBLICA             PICHINCHA              SCOPUS
# ...

# %%
data.to_csv('data.csv', sep=';')
